# %%
from numba import njit
import functions_new_jit as func
import importlib
importlib.reload(func)

##########################################################################################################################################

import numpy as np
import matplotlib.pyplot as plt
import random as rd
from IPython.display import clear_output

# %% [markdown]
# "simulate_riot_sectors" function test

# %%
N = 120
average = 45
deviation = 12

agents = func.create_agents(N,average,deviation)
sector0_size = 20
sector1_size = 100

system = func.System(agents, sector0_size, sector1_size)

steps = 100

progression = func.simulate_riot_sectors(system, steps)

plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N)
plt.show()

# %% [markdown]
# "simulate_riot_sectors" heatmaps

# %%
@njit
def zas():
    N = 120
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 20
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)
        
        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors(system, steps)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas()

"""f1 = open("simulate_riot_sectors_0.txt", "w")
f2 = open("simulate_riot_sectors_total.txt", "w")
f3 = open("simulate_riot_sectors_menor.txt", "w")
f4 = open("simulate_riot_sectors_maior.txt", "w")"""

"""for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()"""

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_exit" function test

# %%
N = 120
average = 45
deviaition = 20

sector0_size = 20
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 100

progression = func.simulate_riot_sectors_exit(system, steps)

plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N)
plt.show()

# %% [markdown]
# "simulate_riot_sectors_exit" heatmaps

# %%
@njit
def zas2():
    N = 120
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 20
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_exit(system, steps)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas2()

"""f1 = open("simulate_riot_sectors_exit_0.txt", "w")
f2 = open("simulate_riot_sectors_exit_total.txt", "w")
f3 = open("simulate_riot_sectors_exit_menor.txt", "w")
f4 = open("simulate_riot_sectors_exit_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()"""

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

# %% [markdown]
# "simulate_riot_sectors_migration" function test (migration_probability = 0.01)

# %%
N = 200
average = 45
deviaition = 20

sector0_size = 100
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 100

progression = func.simulate_riot_sectors_migration(system, steps, 0.01)


plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N)
plt.show()

# %% [markdown]
# "simulate_riot_sectors_migration" heatmaps

# %%
@njit
def zas3():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration(system, steps, 0.01)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas3()

f1 = open("simulate_riot_sectors_migration_001_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_001_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_001_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_001_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration" function test (migration_probability = 0.5)

# %%
N = 200
average = 45
deviaition = 20

sector0_size = 100
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 100

progression = func.simulate_riot_sectors_migration(system, steps, 0.5)


plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N)
plt.show()

# %%
@njit
def zas3_2():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration(system, steps, 0.5)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas3_2()

f1 = open("simulate_riot_sectors_migration_05_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_05_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_05_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_05_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration_exit" function test (migration_probability = 0.01)

# %%
N = 200
average = 45
deviaition = 20

sector0_size = 100
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 1000

migration_probability = 0.01

progression = func.simulate_riot_sectors_migration_exit(system, steps, 0.01)


plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N)
plt.show()

# %% [markdown]
# "simulate_riot_sectors_migration_exit" heatmaps

# %%
@njit
def zas4():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration_exit(system, steps, 0.01)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas4()

f1 = open("simulate_riot_sectors_migration_exit_001_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_exit_001_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_exit_001_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_exit_001_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration_exit" function test (migration_probability = 0.5)

# %%
N = 200
average = 45
deviaition = 20

sector0_size = 100
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 1000

migration_probability = 0.01

progression = func.simulate_riot_sectors_migration_exit(system, steps,migration_probability,0.5)


plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N)
plt.show()

# %%
@njit
def zas4_2():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration_exit(system, steps, 0.5)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas4()

f1 = open("simulate_riot_sectors_migration_exit_05_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_exit_05_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_exit_05_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_exit_05_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration_gregarious" function test

# %%
import time
N = 200
average = 55
deviaition = 20

sector0_size = 150
sector1_size = 150

agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 100

progression = func.simulate_riot_sectors_migration_gregarious(system, steps)


et = time.time()

# get the execution time

plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N+5)
plt.show()

# %% [markdown]
# "simulate_riot_sectors_gregarious" heatmaps

# %%
@njit
def zas5():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration_gregarious(system, steps)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas5()

f1 = open("simulate_riot_sectors_gregarious_0.txt", "w")
f2 = open("simulate_riot_sectors_gregarious_total.txt", "w")
f3 = open("simulate_riot_sectors_gregarious_menor.txt", "w")
f4 = open("simulate_riot_sectors_gregarious_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration_gregarious_exit" function test

# %%
N = 200
average = 35
deviaition = 20

sector0_size = 150
sector1_size = 150
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 100

progression = func.simulate_riot_sectors_migration_gregarious_exit(system, steps)


plt.figure()
plt.plot(progression[0])
plt.plot(progression[1])
plt.ylim(-3,N+5)
plt.show()

# %% [markdown]
# "simulate_riot_sectors_migration_gregarious_exit" heatmaps

# %%
@njit
def zas6():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration_gregarious_exit(system, steps)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas5()

f1 = open("simulate_riot_sectors_migration_gregarious_exit_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_gregarious_exit_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_gregarious_exit_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_gregarious_exit_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration_exit_unidirectional" function test (migration_probability = 0.01)

# %%
N = 200
average = 40
deviaition = 20

sector0_size = 100
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 1000

migration_probability = 0.01

progression = func.simulate_riot_sectors_migration_exit_unidirectional(system, steps, 0.01)


plt.figure()
plt.plot(progression[0], color='b', label='sector0')
plt.plot(progression[1], color='r', label='sector1')
plt.ylim(-3,N)
plt.legend()
plt.show()

# %%
@njit
def zas8():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration_exit_unidirectional(system, steps, 0.01)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas8()

f1 = open("simulate_riot_sectors_migration_exit_unidirectional_001_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_exit_unidirectional_001_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_exit_unidirectional_001_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_exit_unidirectional_001_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0

# %% [markdown]
# "simulate_riot_sectors_migration_exit_unidirectional" function test (migration_probability = 0.5)

# %%
N = 200
average = 37
deviaition = 20

sector0_size = 100
sector1_size = 100
agents0 = func.create_agents(N,average,deviaition)

system = func.System(agents0, sector0_size, sector1_size)

steps = 1000

migration_probability = 0.5

progression = func.simulate_riot_sectors_migration_exit_unidirectional(system, steps, 0.5)


plt.figure()
plt.plot(progression[0], color='b', label='sector0')
plt.plot(progression[1], color='r', label='sector1')
plt.ylim(-3,N)
plt.legend()
plt.show()

# %%
@njit
def zas9():
    N = 200
    averages_sample = np.arange(0,100)  # average value of the normal distribution
    deviations = np.arange(0,100)       # standard deviations of the normal distribution

    sector0_size = 100
    sector1_size = 100

    steps = 100
    simulations = 100

    heat_map_0 = np.zeros((100,100))
    heat_map_total = np.zeros((100,100))
    heat_map_maior = np.zeros((100,100))
    heat_map_menor = np.zeros((100,100))

    for k in averages_sample:
        print(100*k/99)

        for i in deviations:         # a set of simulations per standard deviation value
            average_size_0 = 0
            average_size_total = 0
            average_size_maior = 0
            average_size_menor = 0

            for j in range(simulations):   # riot simulation
                agents = func.create_agents(N,k,i)
                system = func.System(agents, sector0_size, sector1_size)
                final = func.simulate_riot_sectors_migration_exit_unidirectional(system, steps, 0.5)
                average_size_0 += final[0][-1]
                average_size_total += final[0][-1] + final[1][-1]
                average_size_maior += max(final[0][-1],final[1][-1])
                average_size_menor += min(final[0][-1],final[1][-1])

            average_size_0 = average_size_0/simulations
            average_size_total = average_size_total/simulations
            average_size_maior = average_size_maior/simulations
            average_size_menor = average_size_menor/simulations
            heat_map_0[i][k] = average_size_0
            heat_map_total[i][k] = average_size_total
            heat_map_maior[i][k] = average_size_maior
            heat_map_menor[i][k] = average_size_menor

    return heat_map_0, heat_map_total, heat_map_menor, heat_map_maior

# %%
h0, h1, h2, h3 = zas9()

f1 = open("simulate_riot_sectors_migration_exit_unidirectional_05_0.txt", "w")
f2 = open("simulate_riot_sectors_migration_exit_unidirectional_05_total.txt", "w")
f3 = open("simulate_riot_sectors_migration_exit_unidirectional_05_menor.txt", "w")
f4 = open("simulate_riot_sectors_migration_exit_unidirectional_05_maior.txt", "w")

for i in range(100):
    for j in range(100):
        f1.write(str(i) + " " + str(j) + " " + str(h0[i][j]) + "\n")
        f2.write(str(i) + " " + str(j) + " " + str(h1[i][j]) + "\n")
        f3.write(str(i) + " " + str(j) + " " + str(h2[i][j]) + "\n")
        f4.write(str(i) + " " + str(j) + " " + str(h3[i][j]) + "\n")
f1.close()
f2.close()
f3.close()
f4.close()

plt.figure()
plt.imshow(h0, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h1, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h2, origin="lower",cmap="jet")
plt.colorbar()
plt.show()

plt.figure()
plt.imshow(h3, origin="lower",cmap="jet")
plt.colorbar()
plt.show()
# Out:
# 0.0
# 1.0101010101010102
# 2.0202020202020203
# 3.0303030303030303
# 4.040404040404041
# 5.05050505050505
# 6.0606060606060606
# 7.070707070707071
# 8.080808080808081
# 9.090909090909092
# 10.1010101010101
# 11.11111111111111
# 12.121212121212121
# 13.131313131313131
# 14.141414141414142
# 15.151515151515152
# 16.161616161616163
# 17.171717171717173
# 18.181818181818183
# 19.19191919191919
# 20.2020202020202
# 21.21212121212121
# 22.22222222222222
# 23.232323232323232
# 24.242424242424242
# 25.252525252525253
# 26.262626262626263
# 27.272727272727273
# 28.282828282828284
# 29.292929292929294
# 30.303030303030305
# 31.31313131313131
# 32.323232323232325
# 33.333333333333336
# 34.343434343434346
# 35.35353535353536
# 36.36363636363637
# 37.37373737373738
# 38.38383838383838
# 39.39393939393939
# 40.4040404040404
# 41.41414141414141
# 42.42424242424242
# 43.43434343434343
# 44.44444444444444
# 45.45454545454545
# 46.464646464646464
# 47.474747474747474
# 48.484848484848484
# 49.494949494949495
# 50.505050505050505
# 51.515151515151516
# 52.525252525252526
# 53.535353535353536
# 54.54545454545455
# 55.55555555555556
# 56.56565656565657
# 57.57575757575758
# 58.58585858585859
# 59.5959595959596
# 60.60606060606061
# 61.61616161616162
# 62.62626262626262
# 63.63636363636363
# 64.64646464646465
# 65.65656565656566
# 66.66666666666667
# 67.67676767676768
# 68.68686868686869
# 69.6969696969697
# 70.70707070707071
# 71.71717171717172
# 72.72727272727273
# 73.73737373737374
# 74.74747474747475
# 75.75757575757575
# 76.76767676767676
# 77.77777777777777
# 78.78787878787878
# 79.79797979797979
# 80.8080808080808
# 81.81818181818181
# 82.82828282828282
# 83.83838383838383
# 84.84848484848484
# 85.85858585858585
# 86.86868686868686
# 87.87878787878788
# 88.88888888888889
# 89.8989898989899
# 90.9090909090909
# 91.91919191919192
# 92.92929292929293
# 93.93939393939394
# 94.94949494949495
# 95.95959595959596
# 96.96969696969697
# 97.97979797979798
# 98.98989898989899
# 100.0
