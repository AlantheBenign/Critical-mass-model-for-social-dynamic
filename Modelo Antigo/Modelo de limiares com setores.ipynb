# %%
# Essas duas linhas recarregam o arquivo do módulo "funcoes_modelo_de_limiares.py" #
import funcoes as lim
import importlib
importlib.reload(lim)

###########################################################################################################################################

import numpy as np
import matplotlib.pyplot as plt
import random as rd
from IPython.display import clear_output

# %% [markdown]
# Teste da função "simula_greve_setores"

# %%
N = 100
media = 55
desvio_padrao = 20

agentes0 = lim.cria_agentes(N,media,desvio_padrao)
agentes1 = lim.cria_agentes(N,media,desvio_padrao)

sistema = lim.Sistema(agentes0, agentes1)

passos_temporais = 100

(progressao, tamanho_final) = lim.simula_greve_setores(sistema, passos_temporais)


plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
plt.ylim(-3,2*N)
plt.show()

# %% [markdown]
# Teste da função "simula_greve_setores_saida"

# %%
N = 100
media = 37
desvio_padrao = 20

agentes0 = lim.cria_agentes(N,media,desvio_padrao)
agentes1 = lim.cria_agentes(N,media,desvio_padrao)

sistema = lim.Sistema(agentes0, agentes1)

passos_temporais = 100

(progressao, tamanho_final) = lim.simula_greve_setores_saida(sistema, passos_temporais)


plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
plt.ylim(-3,2*N)
plt.show()

# %% [markdown]
# Teste da função "simula_greve_setores_migracao"

# %%
N = 100
media = 65
desvio_padrao = 20

agentes0 = lim.cria_agentes(N,media,desvio_padrao)
agentes1 = lim.cria_agentes(N,media,desvio_padrao)

sistema = lim.Sistema(agentes0, agentes1)
migracao = 0

passos_temporais = 1000

(progressao, tamanho_final, migracao) = lim.simula_greve_setores_migracao(sistema, passos_temporais, migracao)

print(migracao)

plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
plt.ylim(-3,2*N)
plt.show()
# Out:
# 0

# %% [markdown]
# Teste da função "simula_greve_setores_migracao_individual"

# %%
N = 100
#media = 63
#desvio_padrao = 20

agentes0 = lim.cria_agentes(N,80,20)
agentes1 = lim.cria_agentes(N,10,20)

sistema = lim.Sistema(agentes0, agentes1)
migracao = 0.01

passos_temporais = 1000
ligar = 500

(progressao, tamanho_final, migracao) = lim.simula_greve_setores_migracao_individual(sistema, passos_temporais, migracao, ligar)

plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
plt.plot([2*ligar,2*ligar],[-5,2*N])
plt.ylim(-5,2*N)
plt.show()

# %% [markdown]
# Teste da função "simula_greve_setores_migracao_individual_saida"

# %%
N = 100
#media = 63
#desvio_padrao = 20

agentes0 = lim.cria_agentes(N,45,20)
agentes1 = lim.cria_agentes(N,37,20)

sistema = lim.Sistema(agentes0, agentes1)
migracao = 0.01

passos_temporais = 1000
ligar = 500

(progressao, tamanho_final, migracao) = lim.simula_greve_setores_migracao_individual_saida(sistema, passos_temporais, migracao, ligar)

plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
plt.plot([2*ligar,2*ligar],[-5,2*N])
plt.ylim(-5,2*N)
plt.show()

# %% [markdown]
# Teste da função "simula_greve_setores_migracao_individual_gregario"

# %%
importlib.reload(lim)
N = 100
media = 25
desvio_padrao = 10

agentes0 = lim.cria_agentes(N,65,20)
agentes1 = lim.cria_agentes(N,65,20)

sistema = lim.Sistema(agentes0, agentes1)

passos_temporais = 1000
ligar = 500

(progressao, tamanho_final, migracao) = lim.simula_greve_setores_migracao_individual_gregario(sistema, passos_temporais, ligar)

plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
#plt.plot([2*ligar,2*ligar],[-5,2*N])
plt.ylim(-5,2*N+5)
plt.show()

# %% [markdown]
# Teste da função "simula_greve_setores_migracao_individual_gregario-saida"

# %%
importlib.reload(lim)
N = 100
media = 25
desvio_padrao = 10

agentes0 = lim.cria_agentes(N,45,20)
agentes1 = lim.cria_agentes(N,39,20)

sistema = lim.Sistema(agentes0, agentes1)

passos_temporais = 1000
ligar = 500

(progressao, tamanho_final, migracao) = lim.simula_greve_setores_migracao_individual_gregario_saida(sistema, passos_temporais, ligar)

plt.figure()
plt.plot(progressao[0])
plt.plot(progressao[1])
#plt.plot([2*ligar,2*ligar],[-5,2*N])
plt.ylim(-5,2*N+5)
plt.show()
