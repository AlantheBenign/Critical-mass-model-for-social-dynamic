# %% [markdown]
# #### LIBRARIES USED

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
from IPython import display
import time

# %% [markdown]
# #### SEGREGATION MODEL

# %% [markdown]
# The model describes the evolution of an population in a city, that is divided in Q blocks with H sites each. Each site can be occupied by 0 or 1 agent. The agents move around the city according to some rule, for example, maximize its utility. In this model we have two types of agents: residents and merchants. Both move to maximize it's own utility, but they have different utility functions, residents prefer half-fulled blocks and merchants prefer full blocks.

# %% [markdown]
# #### FUNCTIONS'S DEFINITIONS

# %%
vacancy_value = 0
resident_value = 1
merchant_value = 2

# %%
def plot_grid(agents, n, alpha):
    # creates a discrete colormap
    vacancy = np.array([147.0/255, 148.0/255, 150.0/255])     # grey
    agent =  np.array([255.0/255, (alpha) * 255.0/255, 0.0/255])     # red --> yellow
    cyan =  np.array([0.0/255, 200.0/255, 255.0/255])       # cyan
    cmap = colors.ListedColormap([vacancy, agent, cyan])
    # determines the limits of each color:
    bounds = [vacancy_value, resident_value, merchant_value, merchant_value + 1]            
    norm = colors.BoundaryNorm(bounds, cmap.N)

    size = 8
    fig, ax = plt.subplots(figsize=(size,size))
    ax.imshow(agents, cmap=cmap, norm=norm)

    # draws gridlines
    ax.grid(which='major', axis='both', linestyle='-', color='k', linewidth=2)
    ax.set_xticks(np.arange(-0.5, agents.shape[1], n));
    ax.set_yticks(np.arange(-0.5, agents.shape[0], n));

    plt.show()

# %%
def block_code(i,j):
    code = int(np.floor(j/n) + q * np.floor(i/n))
    return code

# %%
def create_city(n, q, agent_density, resident_relative_density):
    vacancy_array = np.array([[-1,-1,-1]])
    agent_array   = np.array([[-1,-1,-1, -1]])
    density_array = np.full(q*q,0.0)
    city_side = n*q
    
    # creates a city without borders, that will be a toroidal grid
    city = np.full((city_side,city_side), vacancy_value)
    residents = 0
    merchants = 0
    
    for code in range(q*q):
        block_x = int((code%q) * n)
        block_y = int(np.floor(code/q) * n)
        
        agents_in_block = 0.0
        
        for di in range(0,n):
            for dj in range(0,n):
                i = block_y + di
                j = block_x + dj
                rnd = np.random.random()
                if rnd <= agent_density:
                    rnd2 = np.random.random()
                    
                    if rnd2 <= resident_relative_density:
                        city[i,j] = resident_value
                        agents_in_block += 1.0
                        residents += 1
                        agent_array = np.append(agent_array, [[block_code(i,j), i, j, resident_value]], axis=0)
                    else:
                        city[i,j] = merchant_value
                        agents_in_block += 1.0
                        merchants += 1
                        agent_array = np.append(agent_array, [[block_code(i,j), i, j, merchant_value]], axis=0)
                else:
                     vacancy_array = np.append(vacancy_array, [[block_code(i,j), i, j]], axis=0)
        
        block_density = agents_in_block/(n*n)
        density_array[code] = block_density 

    vacancy_array = np.delete(vacancy_array, 0,0)
    agent_array = np.delete(agent_array, 0,0)
    
    return city, vacancy_array, agent_array, density_array, residents, merchants

# %%
def utility_function_resident(pho):
    m = 0.5
    if(pho <= 0.5):
        utility = 2*pho
    else:
        utility = 2*(m-1)*pho + 2 - m
    
    return utility

# %%
def utility_function_merchant(pho): 
    utility = pho
    return utility

# %%
def detect_city_utility(density_array, agent_array): 
    #check city utility
    city_utility = 0.0

    for agent in agent_array:
        if(agent[3] == resident_value):
            city_utility += utility_function_resident(density_array[agent[0]])
        else:
            city_utility += utility_function_merchant(density_array[agent[0]])
    
    return city_utility

# %%
def simulation_step(n, alpha, T, city, vacancy_array, agent_array, density_array):
    #we choose an agent and a vancant site in another block, it moves if its utility function increases.
    change = False
    rndV = np.random.randint(0, len(vacancy_array))
    rndA = np.random.randint(0, len(agent_array))
    codeV = vacancy_array[rndV,0] 
    codeA = agent_array[rndA,0]
    phoV = density_array[codeV]
    phoA = density_array[codeA]
    
    iV, jV = vacancy_array[rndV,1:3]
    iA, jA = agent_array[rndA,1:3]
    
    #computing delta city utility
    city_utility = detect_city_utility(density_array, agent_array)
    density_array[codeV] += 1/(n*n)
    density_array[codeA] -= 1/(n*n)
    vacancy_array[rndV] = [codeA,iA,jA]
    agent_array[rndA,0:3] = [codeV,iV,jV]
    new_city_utility = detect_city_utility(density_array, agent_array)
    density_array[codeV] = phoV
    density_array[codeA] = phoA
    vacancy_array[rndV] = [codeV,iV,jV]
    agent_array[rndA,0:3] = [codeA,iA,jA]
    delta_city_utility = new_city_utility - city_utility
    
    #merchant movement condition
    if(agent_array[rndA,3] == merchant_value):
        agent_utility = utility_function_merchant(phoA)
        new_agent_utility = utility_function_merchant(phoV + 1/(n*n))
        
        gain = new_agent_utility - agent_utility
        prob = 1 / (1 + np.exp(-gain*5/T))
        rnd = np.random.random()
        
        if(rnd < prob):
            change = True
    
    #resident movement condition
    elif(agent_array[rndA,3] == resident_value):
        agent_utility = utility_function_resident(phoA)
        new_agent_utility = utility_function_resident(phoV + 1/(n*n))
        delta_agent_utility = new_agent_utility - agent_utility
        
        #computing gain
        gain = delta_agent_utility + alpha * (delta_city_utility - delta_agent_utility)

        #computing movement probability
        prob = 1 / (1 + np.exp(-gain*5/T))
        rnd = np.random.random()
        
        if(rnd < prob):
            change = True
    
    
    if(change):
        #update system
        
        #update vacancy and agent arrays
        vacancy_array[rndV] = [codeA,iA,jA]
        agent_array[rndA,0:3] = [codeV,iV,jV]

        #update city grid
        city[iA,jA] = vacancy_value
        city[iV,jV] = agent_array[rndA,3]
        
        #update density array
        density_array[codeV] += 1/(n*n)
        density_array[codeA] -= 1/(n*n)
    
    return city, vacancy_array, agent_array, density_array

# %% [markdown]
# #### MODEL TESTING

# %% [markdown]
# #### T = 0

# %%
n = 15
q = 6
T = 1
alpha = 0
agent_density = 0.5
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = steps/20
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_12756\1141515736.py:49: RuntimeWarning: divide by zero encountered in double_scalars
#   prob = 1 / (1 + np.exp(-gain*5/T))
# C:\Users\Alan\AppData\Local\Temp\ipykernel_12756\1141515736.py:49: RuntimeWarning: invalid value encountered in double_scalars
#   prob = 1 / (1 + np.exp(-gain*5/T))
# C:\Users\Alan\AppData\Local\Temp\ipykernel_12756\1141515736.py:33: RuntimeWarning: invalid value encountered in double_scalars
#   prob = 1 / (1 + np.exp(-gain*5/T))
#
# KeyboardInterrupt

# %%
n = 15
q = 6
T = 1
alpha = 0.0001
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)
# Out:
# C:\Users\Alan\AppData\Local\Temp\ipykernel_5452\653272499.py:46: RuntimeWarning: overflow encountered in exp
#   prob = 1 / (1 + np.exp(-gain/T))
# C:\Users\Alan\AppData\Local\Temp\ipykernel_5452\653272499.py:30: RuntimeWarning: overflow encountered in exp
#   prob = 1/(1 + np.exp(-gain/T))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[102], line 16
#      14 passo = 2000
#      15 for a in range(steps):
# ---> 16     city, vacancy_array, agent_array, density_array = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array)
#      18     if(a%passo == 0):
#      19         plot_grid(city, n, alpha)
#
# Cell In[101], line 18, in simulation_step(n, alpha, T, city, vacancy_array, agent_array, density_array)
#      16 density_array[codeV] += 1/(n*n)
#      17 density_array[codeA] -= 1/(n*n)
# ---> 18 new_city_utility = detect_city_utility(n, density_array, agent_array)
#      19 density_array[codeV] = phoV
#      20 density_array[codeA] = phoA
#
# Cell In[100], line 7, in detect_city_utility(n, density_array, agent_array)
#       5 for agent in agent_array:
#       6     if(agent[3] == resident_value):
# ----> 7         city_utility += utility_function_resident(density_array[agent[0]])
#       8     else:
#       9         city_utility += utility_function_merchant(density_array[agent[0]])
#
# KeyboardInterrupt:

# %% [markdown]
# #### T = 0.01

# %%
n = 15
q = 6
T = 0.01
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# #### T = 0.1

# %%
n = 15
q = 6
T = 0.1
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# #### T = 0.2

# %%
n = 15
q = 6
T = 0.2
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# #### T = 0.4

# %%
n = 15
q = 6
T = 0.4
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# #### T = 0.6

# %%
n = 15
q = 6
T = 0.6
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# #### T = 0.8

# %%
n = 15
q = 6
T = 0.8
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# #### T = 1

# %%
n = 15
q = 6
T = 1
alpha = 0
agent_density = 0.4
resident_relative_density = 0.9

city, vacancy_array, agent_array, density_array, residents, merchants = create_city(n, q, agent_density, resident_relative_density)

print(residents/(residents+merchants),merchants/(residents+merchants), (residents+merchants)/(n*n*q*q))
time.sleep(1)

steps = 100000
passo = 2000
for a in range(steps):
    city, vacancy_array, agent_array, density_array = simulation_step(n, T, city, vacancy_array, agent_array, density_array)
    
    if(a%passo == 0):
        plot_grid(city, n, alpha)
        print(str(a/steps * 100) + '%')
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.1

# %%
n = 15
q = 6
T = 0
alpha = 0.1
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.2

# %%
n = 15
q = 6
T = 0
alpha = 0.2
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.3

# %%
n = 15
q = 6
T = 0
alpha = 0.3
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.4

# %%
n = 15
q = 6
T = 0
alpha = 0.4
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.5

# %%
n = 15
q = 6
T = 0
alpha = 0.5
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.6

# %%
n = 15
q = 6
T = 0
alpha = 0.6
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.7

# %%
n = 15
q = 6
T = 0
alpha = 0.7
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.8

# %%
n = 15
q = 6
T = 0
alpha = 0.8
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)

# %% [markdown]
# ##### Alpha = 0.9

# %%
n = 15
q = 6
T = 0
alpha = 0.9
agent_density = 0.4

city, vacancy_array, agent_array, density_array = create_city(n, q, agent_density)

city_utility = detect_city_utility(n, density_array)

steps = 100000
passo = 500
for a in range(steps):
    city, vacancy_array, agent_array, density_array, city_utility = simulation_step(n, T, alpha, city, vacancy_array, agent_array, density_array, city_utility)
    
    if(a%passo == 0):
        print(str(a/steps * 100) + '%')
        plot_grid(city,n, alpha)
        time.sleep(0.1)
        display.clear_output(wait=True)
        
plot_grid(city,n, alpha)
